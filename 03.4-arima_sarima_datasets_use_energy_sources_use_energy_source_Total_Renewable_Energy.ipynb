# %%
import pandas as pd
import numpy as np
from pmdarima import auto_arima
import plotly.graph_objects as go
from sklearn.metrics import mean_absolute_error, mean_squared_error
import os

# %% [markdown]
# # Using energy Source Datasets

# %% [markdown]
# # Source of Energy Petroleum

# %%
# Read the Excel file
# Data_Status: Indicates the status of the data. The value "2020F" suggests that it is a forecast for the year 2020.
# State: Represents the state for which the data is recorded (in this case, "CA" for California).
# MSN: Stands for "Monthly State Names" and refers to the specific energy metric or variable being measured. Examples include ARICD, ARICV, ARTCD, ARTCV, ARTXD, WWTXV, WXICD, WXICV, ZWCDP, ZWHDP.
df = pd.read_excel('Datasets/use_energy_source.xlsx' , sheet_name='Total Renewable Energy')

# %%
df.head()
# Out:
#   State    1960    1961    1962    1963    1964    1965    1966    1967
# 0    AK    6800    7313    7453    7793    8102    8519    8328    8457  \
# 1    AL  112809  118021  125564  112682  137992  121888  121238  144384
# 2    AR   48104   51144   47637   41897   42732   46425   51697   46124
# 3    AZ   36181   35083   34533   34861   34271   50095   58060   56423
# 4    CA  270161  248178  329046  360333  331757  418518  375877  473192
#
#      1968  ...    2011    2012    2013    2014    2015     2016     2017
# 0    8486  ...   16702   17831   18931   22762   23828    26261    24457  \
# 1  129673  ...  279973  265965  336863  293899  284415   259541   285128
# 2   64986  ...  135136  125381  132370  131627  129282   127846   121650
# 3   63456  ...  129528  114932  119706  139847  149090   162081   172809
# 4  397366  ...  947170  811259  858614  865271  863080  1059626  1253699
#
#       2018     2019     2020
# 0    25008    23619    25546
# 1   301239   298627   308293
# 2   124853   132224   118159
# 3   179625   174665   177724
# 4  1157437  1277304  1140522
#
# [5 rows x 62 columns]

# %% [markdown]
# # Data statistics

# %%
df.head()
# Out:
#   State    1960    1961    1962    1963    1964    1965    1966    1967
# 0    AK    6800    7313    7453    7793    8102    8519    8328    8457  \
# 1    AL  112809  118021  125564  112682  137992  121888  121238  144384
# 2    AR   48104   51144   47637   41897   42732   46425   51697   46124
# 3    AZ   36181   35083   34533   34861   34271   50095   58060   56423
# 4    CA  270161  248178  329046  360333  331757  418518  375877  473192
#
#      1968  ...    2011    2012    2013    2014    2015     2016     2017
# 0    8486  ...   16702   17831   18931   22762   23828    26261    24457  \
# 1  129673  ...  279973  265965  336863  293899  284415   259541   285128
# 2   64986  ...  135136  125381  132370  131627  129282   127846   121650
# 3   63456  ...  129528  114932  119706  139847  149090   162081   172809
# 4  397366  ...  947170  811259  858614  865271  863080  1059626  1253699
#
#       2018     2019     2020
# 0    25008    23619    25546
# 1   301239   298627   308293
# 2   124853   132224   118159
# 3   179625   174665   177724
# 4  1157437  1277304  1140522
#
# [5 rows x 62 columns]

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964
# count  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  \
# mean   1.126232e+05  1.135472e+05  1.199017e+05  1.190936e+05  1.240481e+05
# std    4.050458e+05  4.090107e+05  4.326671e+05  4.307541e+05  4.486107e+05
# min    1.550000e+02  1.630000e+02  1.660000e+02  1.480000e+02  1.380000e+02
# 25%    1.665650e+04  1.545300e+04  1.587325e+04  1.543500e+04  1.590225e+04
# 50%    3.657350e+04  3.540300e+04  3.591400e+04  3.515900e+04  3.596550e+04
# 75%    6.700150e+04  6.245475e+04  6.324475e+04  6.166525e+04  6.133750e+04
# max    2.928205e+06  2.952227e+06  3.117444e+06  3.096431e+06  3.225249e+06
#
#                1965          1966          1967          1968          1969
# count  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  \
# mean   1.306083e+05  1.320178e+05  1.419312e+05  1.451021e+05  1.574958e+05
# std    4.729927e+05  4.782125e+05  5.153968e+05  5.268598e+05  5.732129e+05
# min    1.200000e+02  1.110000e+02  1.120000e+02  1.200000e+02  1.080000e+02
# 25%    1.604750e+04  1.607150e+04  1.647275e+04  1.830475e+04  1.862350e+04
# 50%    3.850950e+04  4.064250e+04  3.867700e+04  4.212800e+04  4.309150e+04
# 75%    6.212725e+04  6.377075e+04  6.287450e+04  6.519700e+04  6.752425e+04
# max    3.395816e+06  3.432463e+06  3.690213e+06  3.772655e+06  4.094893e+06
#
#        ...          2011          2012          2013          2014
# count  ...  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  \
# mean   ...  3.540641e+05  3.403789e+05  3.625080e+05  3.739050e+05
# std    ...  1.268327e+06  1.218371e+06  1.295294e+06  1.335706e+06
# min    ...  1.323000e+03  1.110000e+03  1.177000e+03  1.313000e+03
# 25%    ...  7.168225e+04  6.957225e+04  7.620275e+04  7.717200e+04
# 50%    ...  1.355080e+05  1.318815e+05  1.357030e+05  1.538135e+05
# 75%    ...  1.973868e+05  1.909978e+05  2.300575e+05  2.242448e+05
# max    ...  9.205666e+06  8.849852e+06  9.425206e+06  9.721530e+06
#
#                2015          2016          2017          2018          2019
# count  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  \
# mean   3.731333e+05  3.981326e+05  4.260322e+05  4.351386e+05  4.372711e+05
# std    1.332498e+06  1.423831e+06  1.524952e+06  1.556235e+06  1.564566e+06
# min    1.831000e+03  2.193000e+03  2.257000e+03  2.662000e+03  3.050000e+03
# 25%    7.396650e+04  7.616950e+04  8.015775e+04  8.880150e+04  8.373925e+04
# 50%    1.505840e+05  1.561300e+05  1.618365e+05  1.642805e+05  1.678610e+05
# 75%    2.364822e+05  2.408518e+05  2.516818e+05  2.720818e+05  2.801482e+05
# max    9.701466e+06  1.035145e+07  1.107684e+07  1.131360e+07  1.136905e+07
#
#                2020
# count  5.200000e+01
# mean   4.388868e+05
# std    1.570293e+06
# min    3.024000e+03
# 25%    7.777950e+04
# 50%    1.708115e+05
# 75%    2.882250e+05
# max    1.141106e+07
#
# [8 rows x 61 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 62 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   52 non-null     object
#  1   1960    52 non-null     int64
#  2   1961    52 non-null     int64
#  3   1962    52 non-null     int64
#  4   1963    52 non-null     int64
#  5   1964    52 non-null     int64
#  6   1965    52 non-null     int64
#  7   1966    52 non-null     int64
#  8   1967    52 non-null     int64
#  9   1968    52 non-null     int64
#  10  1969    52 non-null     int64
#  11  1970    52 non-null     int64
#  12  1971    52 non-null     int64
#  13  1972    52 non-null     int64
#  14  1973    52 non-null     int64
#  15  1974    52 non-null     int64
#  16  1975    52 non-null     int64
#  17  1976    52 non-null     int64
#  18  1977    52 non-null     int64
#  19  1978    52 non-null     int64
#  20  1979    52 non-null     int64
#  21  1980    52 non-null     int64
#  22  1981    52 non-null     int64
#  23  1982    52 non-null     int64
#  24  1983    52 non-null     int64
#  25  1984    52 non-null     int64
#  26  1985    52 non-null     int64
#  27  1986    52 non-null     int64
#  28  1987    52 non-null     int64
#  29  1988    52 non-null     int64
#  30  1989    52 non-null     int64
#  31  1990    52 non-null     int64
#  32  1991    52 non-null     int64
#  33  1992    52 non-null     int64
#  34  1993    52 non-null     int64
#  35  1994    52 non-null     int64
#  36  1995    52 non-null     int64
#  37  1996    52 non-null     int64
#  38  1997    52 non-null     int64
#  39  1998    52 non-null     int64
#  40  1999    52 non-null     int64
#  41  2000    52 non-null     int64
#  42  2001    52 non-null     int64
#  43  2002    52 non-null     int64
#  44  2003    52 non-null     int64
#  45  2004    52 non-null     int64
#  46  2005    52 non-null     int64
#  47  2006    52 non-null     int64
#  48  2007    52 non-null     int64
#  49  2008    52 non-null     int64
#  50  2009    52 non-null     int64
#  51  2010    52 non-null     int64
#  52  2011    52 non-null     int64
#  53  2012    52 non-null     int64
#  54  2013    52 non-null     int64
#  55  2014    52 non-null     int64
#  56  2015    52 non-null     int64
#  57  2016    52 non-null     int64
#  58  2017    52 non-null     int64
#  59  2018    52 non-null     int64
#  60  2019    52 non-null     int64
#  61  2020    52 non-null     int64
# dtypes: int64(61), object(1)
# memory usage: 25.3+ KB

# %% [markdown]
# # Transformation of Data

# %%
df_trans = df.melt(id_vars=['State'] , var_name='Year', value_name='Yearly Data')
df_trans['Year'] = pd.to_datetime(df_trans['Year'], format='%Y')

df_trans
# Out:
#      State       Year  Yearly Data
# 0       AK 1960-01-01         6800
# 1       AL 1960-01-01       112809
# 2       AR 1960-01-01        48104
# 3       AZ 1960-01-01        36181
# 4       CA 1960-01-01       270161
# ...    ...        ...          ...
# 3167    WA 2020-01-01       884943
# 3168    WI 2020-01-01       183122
# 3169    WV 2020-01-01        48051
# 3170    WY 2020-01-01        68452
# 3171    US 2020-01-01     11411059
#
# [3172 rows x 3 columns]

# %% [markdown]
# # Modeling the Data
# ## Using ARIMA Model

# %%
os.makedirs('Plots/use_energy_source_Total_Renewable_Energy/Arima_results_plots',exist_ok=True)

for State in df_trans['State'].unique():
        try:
            
            fig = go.Figure()

            # Get the energy consumption data for the current country and sector
            df_filter = df_trans[df_trans['State'] == State ][['Year', 'Yearly Data']]
            df_filter_index = df_filter.set_index('Year')

            train_data = df_filter[:-5]
            test_data = df_filter[-5:]
            
            # Prepare the data for modeling
            years = df_filter_index.index
            energy_consumption = df_filter_index.values.flatten()

                    # Split the data into training and testing
            # Use all data except the last 5 years for training
            Horizan = -5
            train_data = energy_consumption[:Horizan]
            test_data = energy_consumption[Horizan:]  # Use the last 5 years for testing

            # Fit the auto ARIMA model
            model = auto_arima(train_data, seasonal=False)
            model.fit(train_data)

            # Generate predictions
            predictions = model.predict(n_periods=len(test_data))
            predictions_ahead_in_future = model.predict(n_periods=len(test_data)+15)

            # Calculate evaluation metrics
            mae = mean_absolute_error(test_data, predictions)
            mse = mean_squared_error(test_data, predictions)
            mape = np.mean(np.abs((test_data - predictions) / test_data)) * 100

            print('Mean Absolute Error (MAE):', np.round(mae,2))
            print('Mean Squared Error (MSE):', np.round(mse,2))
            print('Mean Absolute Percentage Error (MAPE):', np.round(mape,2))
            
            # Plot the training data
            fig.add_trace(go.Scatter(
                x=years[:Horizan], y=train_data, mode='lines+markers', name='Training Data'))

            # Plot the predictions
            fig.add_trace(go.Scatter(
                x=years[Horizan:], y=test_data, mode='lines+markers', name='Actual'))
            fig.add_trace(go.Scatter(
                x=years[Horizan:], y=predictions, mode='lines+markers', name='Predicted'))

            fig.add_trace(go.Scatter(
                x=pd.date_range(start = years[Horizan],periods=15,freq='Y'), y=predictions_ahead_in_future, mode='lines+markers', name='Prediction till 2030'))

            # Update the layout
            fig.update_layout(title=f'Total Renewable Energy : Energy Consumption Forecast State : {State} using ARIMA Model',
                            xaxis_title='Year', yaxis_title='Energy Consumption')

            # Show the plot
            fig.show()
            # print(State,msn)
            fig.write_image(f'Plots/use_energy_source_Total_Renewable_Energy/Arima_results_plots/{State}.png')
            # break
        except:
            print('Error occoured in Combination State : {} and MSN : {} Due NaN Value'.format(State,mse))
# Out:
# Mean Absolute Error (MAE): 1798.6
# Mean Squared Error (MSE): 3704183.82
# Mean Absolute Percentage Error (MAPE): 7.14
# Mean Absolute Error (MAE): 15540.23
# Mean Squared Error (MSE): 320995276.27
# Mean Absolute Percentage Error (MAPE): 5.42
# Mean Absolute Error (MAE): 5512.4
# Mean Squared Error (MSE): 42460410.8
# Mean Absolute Percentage Error (MAPE): 4.52
# Mean Absolute Error (MAE): 24290.8
# Mean Squared Error (MSE): 627545969.6
# Mean Absolute Percentage Error (MAPE): 13.9
# Mean Absolute Error (MAE): 254190.12
# Mean Squared Error (MSE): 71610555757.11
# Mean Absolute Percentage Error (MAPE): 21.21
# Mean Absolute Error (MAE): 14182.2
# Mean Squared Error (MSE): 222234931.76
# Mean Absolute Percentage Error (MAPE): 8.15
# Mean Absolute Error (MAE): 1210.4
# Mean Squared Error (MSE): 2711860.4
# Mean Absolute Percentage Error (MAPE): 2.47
# Mean Absolute Error (MAE): 1002.59
# Mean Squared Error (MSE): 1199367.59
# Mean Absolute Percentage Error (MAPE): 36.39
# Mean Absolute Error (MAE): 1029.53
# Mean Squared Error (MSE): 1284262.09
# Mean Absolute Percentage Error (MAPE): 12.74
# Mean Absolute Error (MAE): 4574.59
# Mean Squared Error (MSE): 28400861.87
# Mean Absolute Percentage Error (MAPE): 1.5
# Mean Absolute Error (MAE): 8282.12
# Mean Squared Error (MSE): 85615973.55
# Mean Absolute Percentage Error (MAPE): 2.73
# Mean Absolute Error (MAE): 1270.25
# Mean Squared Error (MSE): 2281239.92
# Mean Absolute Percentage Error (MAPE): 4.04
# Mean Absolute Error (MAE): 7598.66
# Mean Squared Error (MSE): 112132412.68
# Mean Absolute Percentage Error (MAPE): 1.51
# Mean Absolute Error (MAE): 13516.4
# Mean Squared Error (MSE): 274501459.6
# Mean Absolute Percentage Error (MAPE): 7.74
# Mean Absolute Error (MAE): 10079.93
# Mean Squared Error (MSE): 128690886.85
# Mean Absolute Percentage Error (MAPE): 3.48
# Mean Absolute Error (MAE): 4030.24
# Mean Squared Error (MSE): 23649287.01
# Mean Absolute Percentage Error (MAPE): 2.18
# Mean Absolute Error (MAE): 17618.17
# Mean Squared Error (MSE): 393727030.03
# Mean Absolute Percentage Error (MAPE): 8.07
# Mean Absolute Error (MAE): 9565.21
# Mean Squared Error (MSE): 110616102.28
# Mean Absolute Percentage Error (MAPE): 9.35
# Mean Absolute Error (MAE): 9002.0
# Mean Squared Error (MSE): 115666992.0
# Mean Absolute Percentage Error (MAPE): 5.65
# Mean Absolute Error (MAE): 15305.85
# Mean Squared Error (MSE): 253564188.28
# Mean Absolute Percentage Error (MAPE): 15.73
# Mean Absolute Error (MAE): 7208.42
# Mean Squared Error (MSE): 77234014.67
# Mean Absolute Percentage Error (MAPE): 8.9
# Mean Absolute Error (MAE): 17636.8
# Mean Squared Error (MSE): 352817436.8
# Mean Absolute Percentage Error (MAPE): 11.9
# Mean Absolute Error (MAE): 9394.85
# Mean Squared Error (MSE): 125100816.29
# Mean Absolute Percentage Error (MAPE): 3.95
# Mean Absolute Error (MAE): 18201.32
# Mean Squared Error (MSE): 565391138.89
# Mean Absolute Percentage Error (MAPE): 6.25
# Mean Absolute Error (MAE): 14217.0
# Mean Squared Error (MSE): 285906558.2
# Mean Absolute Percentage Error (MAPE): 12.33
# Mean Absolute Error (MAE): 2967.4
# Mean Squared Error (MSE): 11963863.4
# Mean Absolute Percentage Error (MAPE): 4.17
# Mean Absolute Error (MAE): 9092.74
# Mean Squared Error (MSE): 113178132.47
# Mean Absolute Percentage Error (MAPE): 6.37
# Mean Absolute Error (MAE): 52245.1
# Mean Squared Error (MSE): 3382000951.02
# Mean Absolute Percentage Error (MAPE): 19.27
# Mean Absolute Error (MAE): 45253.01
# Mean Squared Error (MSE): 2291275964.47
# Mean Absolute Percentage Error (MAPE): 27.55
# Mean Absolute Error (MAE): 4336.66
# Mean Squared Error (MSE): 25014352.6
# Mean Absolute Percentage Error (MAPE): 2.28
# Mean Absolute Error (MAE): 8713.18
# Mean Squared Error (MSE): 112882309.41
# Mean Absolute Percentage Error (MAPE): 15.3
# Mean Absolute Error (MAE): 2134.2
# Mean Squared Error (MSE): 6870193.99
# Mean Absolute Percentage Error (MAPE): 2.58
# Mean Absolute Error (MAE): 34812.02
# Mean Squared Error (MSE): 1390114083.59
# Mean Absolute Percentage Error (MAPE): 37.06
# Mean Absolute Error (MAE): 30209.0
# Mean Squared Error (MSE): 1008859718.2
# Mean Absolute Percentage Error (MAPE): 25.6
# Mean Absolute Error (MAE): 31705.0
# Mean Squared Error (MSE): 1273867531.4
# Mean Absolute Percentage Error (MAPE): 6.49
# Mean Absolute Error (MAE): 2615.6
# Mean Squared Error (MSE): 10139870.4
# Mean Absolute Percentage Error (MAPE): 1.68
# Mean Absolute Error (MAE): 43002.62
# Mean Squared Error (MSE): 2003730535.12
# Mean Absolute Percentage Error (MAPE): 13.78
# Mean Absolute Error (MAE): 34920.0
# Mean Squared Error (MSE): 1651751675.6
# Mean Absolute Percentage Error (MAPE): 7.02
# Mean Absolute Error (MAE): 12406.65
# Mean Squared Error (MSE): 273311873.42
# Mean Absolute Percentage Error (MAPE): 5.47
# Mean Absolute Error (MAE): 3803.84
# Mean Squared Error (MSE): 20740258.5
# Mean Absolute Percentage Error (MAPE): 32.41
# Mean Absolute Error (MAE): 10888.2
# Mean Squared Error (MSE): 189482756.6
# Mean Absolute Percentage Error (MAPE): 6.46
# Mean Absolute Error (MAE): 21144.6
# Mean Squared Error (MSE): 540620567.4
# Mean Absolute Percentage Error (MAPE): 12.96
# Mean Absolute Error (MAE): 21210.67
# Mean Squared Error (MSE): 620667292.89
# Mean Absolute Percentage Error (MAPE): 10.72
# Mean Absolute Error (MAE): 194536.25
# Mean Squared Error (MSE): 41060617056.01
# Mean Absolute Percentage Error (MAPE): 19.16
# Mean Absolute Error (MAE): 25262.8
# Mean Squared Error (MSE): 672679082.0
# Mean Absolute Percentage Error (MAPE): 42.12
# Mean Absolute Error (MAE): 6491.32
# Mean Squared Error (MSE): 46016575.0
# Mean Absolute Percentage Error (MAPE): 3.75
# Mean Absolute Error (MAE): 1843.21
# Mean Squared Error (MSE): 4631984.82
# Mean Absolute Percentage Error (MAPE): 4.5
# Mean Absolute Error (MAE): 55689.87
# Mean Squared Error (MSE): 4037916389.72
# Mean Absolute Percentage Error (MAPE): 6.33
# Mean Absolute Error (MAE): 4919.4
# Mean Squared Error (MSE): 63930627.8
# Mean Absolute Percentage Error (MAPE): 2.61
# Mean Absolute Error (MAE): 4834.0
# Mean Squared Error (MSE): 27590375.6
# Mean Absolute Percentage Error (MAPE): 9.55
# Mean Absolute Error (MAE): 8588.62
# Mean Squared Error (MSE): 95487726.27
# Mean Absolute Percentage Error (MAPE): 13.9
# Mean Absolute Error (MAE): 1033482.2
# Mean Squared Error (MSE): 1134738089075.32
# Mean Absolute Percentage Error (MAPE): 9.24

# %% [markdown]
# ## Using SARIMA Model

# %%
os.makedirs('Plots/use_energy_source_Total_Renewable_Energy/Sarima_results_plots',exist_ok=True)

for State in df_trans['State'].unique():
        try:
            
            fig = go.Figure()

            # Get the energy consumption data for the current country and sector
            df_filter = df_trans[df_trans['State'] == State ][['Year', 'Yearly Data']]
            df_filter_index = df_filter.set_index('Year')

            train_data = df_filter[:-5]
            test_data = df_filter[-5:]
            
            # Prepare the data for modeling
            years = df_filter_index.index
            energy_consumption = df_filter_index.values.flatten()

                    # Split the data into training and testing
            # Use all data except the last 5 years for training
            Horizan = -5
            train_data = energy_consumption[:Horizan]
            test_data = energy_consumption[Horizan:]  # Use the last 5 years for testing

            # Fit the auto ARIMA model
            model = auto_arima(train_data, seasonal=False)
            model.fit(train_data)

            # Generate predictions
            predictions = model.predict(n_periods=len(test_data))
            predictions_ahead_in_future = model.predict(n_periods=len(test_data)+15)

            # Calculate evaluation metrics
            mae = mean_absolute_error(test_data, predictions)
            mse = mean_squared_error(test_data, predictions)
            mape = np.mean(np.abs((test_data - predictions) / test_data)) * 100

            print('Mean Absolute Error (MAE):', np.round(mae,2))
            print('Mean Squared Error (MSE):', np.round(mse,2))
            print('Mean Absolute Percentage Error (MAPE):', np.round(mape,2))
            
            # Plot the training data
            fig.add_trace(go.Scatter(
                x=years[:Horizan], y=train_data, mode='lines+markers', name='Training Data'))

            # Plot the predictions
            fig.add_trace(go.Scatter(
                x=years[Horizan:], y=test_data, mode='lines+markers', name='Actual'))
            fig.add_trace(go.Scatter(
                x=years[Horizan:], y=predictions, mode='lines+markers', name='Predicted'))

            fig.add_trace(go.Scatter(
                x=pd.date_range(start = years[Horizan],periods=15,freq='Y'), y=predictions_ahead_in_future, mode='lines+markers', name='Prediction till 2030'))

            # Update the layout
            fig.update_layout(title=f'Total Renewable Energy : Energy Consumption Forecast State : {State} using SARIMA Model',
                            xaxis_title='Year', yaxis_title='Energy Consumption')

            # Show the plot
            fig.show()
            # print(State,msn)
            fig.write_image(f'Plots/use_energy_source_Total_Renewable_Energy/Sarima_results_plots/{State}.png')
            # break
        except:
            print('Error occoured in Combination State : {} and MSN : {} Due NaN Value'.format(State,mse))
        # break
# Out:
# Mean Absolute Error (MAE): 1798.6
# Mean Squared Error (MSE): 3704183.82
# Mean Absolute Percentage Error (MAPE): 7.14
# Mean Absolute Error (MAE): 15540.23
# Mean Squared Error (MSE): 320995276.27
# Mean Absolute Percentage Error (MAPE): 5.42
# Mean Absolute Error (MAE): 5512.4
# Mean Squared Error (MSE): 42460410.8
# Mean Absolute Percentage Error (MAPE): 4.52
# Mean Absolute Error (MAE): 24290.8
# Mean Squared Error (MSE): 627545969.6
# Mean Absolute Percentage Error (MAPE): 13.9
# Mean Absolute Error (MAE): 254190.12
# Mean Squared Error (MSE): 71610555757.11
# Mean Absolute Percentage Error (MAPE): 21.21
# Mean Absolute Error (MAE): 14182.2
# Mean Squared Error (MSE): 222234931.76
# Mean Absolute Percentage Error (MAPE): 8.15
# Mean Absolute Error (MAE): 1210.4
# Mean Squared Error (MSE): 2711860.4
# Mean Absolute Percentage Error (MAPE): 2.47
# Mean Absolute Error (MAE): 1002.59
# Mean Squared Error (MSE): 1199367.59
# Mean Absolute Percentage Error (MAPE): 36.39
# Mean Absolute Error (MAE): 1029.53
# Mean Squared Error (MSE): 1284262.09
# Mean Absolute Percentage Error (MAPE): 12.74
# Mean Absolute Error (MAE): 4574.59
# Mean Squared Error (MSE): 28400861.87
# Mean Absolute Percentage Error (MAPE): 1.5
# Mean Absolute Error (MAE): 8282.12
# Mean Squared Error (MSE): 85615973.55
# Mean Absolute Percentage Error (MAPE): 2.73
# Mean Absolute Error (MAE): 1270.25
# Mean Squared Error (MSE): 2281239.92
# Mean Absolute Percentage Error (MAPE): 4.04
# Mean Absolute Error (MAE): 7598.66
# Mean Squared Error (MSE): 112132412.68
# Mean Absolute Percentage Error (MAPE): 1.51
# Mean Absolute Error (MAE): 13516.4
# Mean Squared Error (MSE): 274501459.6
# Mean Absolute Percentage Error (MAPE): 7.74
# Mean Absolute Error (MAE): 10079.93
# Mean Squared Error (MSE): 128690886.85
# Mean Absolute Percentage Error (MAPE): 3.48
# Mean Absolute Error (MAE): 4030.24
# Mean Squared Error (MSE): 23649287.01
# Mean Absolute Percentage Error (MAPE): 2.18
# Mean Absolute Error (MAE): 17618.17
# Mean Squared Error (MSE): 393727030.03
# Mean Absolute Percentage Error (MAPE): 8.07
# Mean Absolute Error (MAE): 9565.21
# Mean Squared Error (MSE): 110616102.28
# Mean Absolute Percentage Error (MAPE): 9.35
# Mean Absolute Error (MAE): 9002.0
# Mean Squared Error (MSE): 115666992.0
# Mean Absolute Percentage Error (MAPE): 5.65
# Mean Absolute Error (MAE): 15305.85
# Mean Squared Error (MSE): 253564188.28
# Mean Absolute Percentage Error (MAPE): 15.73
# Mean Absolute Error (MAE): 7208.42
# Mean Squared Error (MSE): 77234014.67
# Mean Absolute Percentage Error (MAPE): 8.9
# Mean Absolute Error (MAE): 17636.8
# Mean Squared Error (MSE): 352817436.8
# Mean Absolute Percentage Error (MAPE): 11.9
# Mean Absolute Error (MAE): 9394.85
# Mean Squared Error (MSE): 125100816.29
# Mean Absolute Percentage Error (MAPE): 3.95
# Mean Absolute Error (MAE): 18201.32
# Mean Squared Error (MSE): 565391138.89
# Mean Absolute Percentage Error (MAPE): 6.25
# Mean Absolute Error (MAE): 14217.0
# Mean Squared Error (MSE): 285906558.2
# Mean Absolute Percentage Error (MAPE): 12.33
# Mean Absolute Error (MAE): 2967.4
# Mean Squared Error (MSE): 11963863.4
# Mean Absolute Percentage Error (MAPE): 4.17
# Mean Absolute Error (MAE): 9092.74
# Mean Squared Error (MSE): 113178132.47
# Mean Absolute Percentage Error (MAPE): 6.37
# Mean Absolute Error (MAE): 52245.1
# Mean Squared Error (MSE): 3382000951.02
# Mean Absolute Percentage Error (MAPE): 19.27
# Mean Absolute Error (MAE): 45253.01
# Mean Squared Error (MSE): 2291275964.47
# Mean Absolute Percentage Error (MAPE): 27.55
# Mean Absolute Error (MAE): 4336.66
# Mean Squared Error (MSE): 25014352.6
# Mean Absolute Percentage Error (MAPE): 2.28
# Mean Absolute Error (MAE): 8713.18
# Mean Squared Error (MSE): 112882309.41
# Mean Absolute Percentage Error (MAPE): 15.3
# Mean Absolute Error (MAE): 2134.2
# Mean Squared Error (MSE): 6870193.99
# Mean Absolute Percentage Error (MAPE): 2.58
# Mean Absolute Error (MAE): 34812.02
# Mean Squared Error (MSE): 1390114083.59
# Mean Absolute Percentage Error (MAPE): 37.06
# Mean Absolute Error (MAE): 30209.0
# Mean Squared Error (MSE): 1008859718.2
# Mean Absolute Percentage Error (MAPE): 25.6
# Mean Absolute Error (MAE): 31705.0
# Mean Squared Error (MSE): 1273867531.4
# Mean Absolute Percentage Error (MAPE): 6.49
# Mean Absolute Error (MAE): 2615.6
# Mean Squared Error (MSE): 10139870.4
# Mean Absolute Percentage Error (MAPE): 1.68
# Mean Absolute Error (MAE): 43002.62
# Mean Squared Error (MSE): 2003730535.12
# Mean Absolute Percentage Error (MAPE): 13.78
# Mean Absolute Error (MAE): 34920.0
# Mean Squared Error (MSE): 1651751675.6
# Mean Absolute Percentage Error (MAPE): 7.02
# Mean Absolute Error (MAE): 12406.65
# Mean Squared Error (MSE): 273311873.42
# Mean Absolute Percentage Error (MAPE): 5.47
# Mean Absolute Error (MAE): 3803.84
# Mean Squared Error (MSE): 20740258.5
# Mean Absolute Percentage Error (MAPE): 32.41
# Mean Absolute Error (MAE): 10888.2
# Mean Squared Error (MSE): 189482756.6
# Mean Absolute Percentage Error (MAPE): 6.46
# Mean Absolute Error (MAE): 21144.6
# Mean Squared Error (MSE): 540620567.4
# Mean Absolute Percentage Error (MAPE): 12.96
# Mean Absolute Error (MAE): 21210.67
# Mean Squared Error (MSE): 620667292.89
# Mean Absolute Percentage Error (MAPE): 10.72
# Mean Absolute Error (MAE): 194536.25
# Mean Squared Error (MSE): 41060617056.01
# Mean Absolute Percentage Error (MAPE): 19.16
# Mean Absolute Error (MAE): 25262.8
# Mean Squared Error (MSE): 672679082.0
# Mean Absolute Percentage Error (MAPE): 42.12
# Mean Absolute Error (MAE): 6491.32
# Mean Squared Error (MSE): 46016575.0
# Mean Absolute Percentage Error (MAPE): 3.75
# Mean Absolute Error (MAE): 1843.21
# Mean Squared Error (MSE): 4631984.82
# Mean Absolute Percentage Error (MAPE): 4.5
# Mean Absolute Error (MAE): 55689.87
# Mean Squared Error (MSE): 4037916389.72
# Mean Absolute Percentage Error (MAPE): 6.33
# Mean Absolute Error (MAE): 4919.4
# Mean Squared Error (MSE): 63930627.8
# Mean Absolute Percentage Error (MAPE): 2.61
# Mean Absolute Error (MAE): 4834.0
# Mean Squared Error (MSE): 27590375.6
# Mean Absolute Percentage Error (MAPE): 9.55
# Mean Absolute Error (MAE): 8588.62
# Mean Squared Error (MSE): 95487726.27
# Mean Absolute Percentage Error (MAPE): 13.9
# Mean Absolute Error (MAE): 1033482.2
# Mean Squared Error (MSE): 1134738089075.32
# Mean Absolute Percentage Error (MAPE): 9.24
