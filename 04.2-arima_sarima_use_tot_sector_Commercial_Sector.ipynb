# %%
import pandas as pd
import numpy as np
from pmdarima import auto_arima
import plotly.graph_objects as go
from sklearn.metrics import mean_absolute_error, mean_squared_error
import os

# %% [markdown]
# # Commercial Sector

# %%
# Read the Excel file
# Data_Status: Indicates the status of the data. The value "2020F" suggests that it is a forecast for the year 2020.
# State: Represents the state for which the data is recorded (in this case, "CA" for California).
# MSN: Stands for "Monthly State Names" and refers to the specific energy metric or variable being measured. Examples include ARICD, ARICV, ARTCD, ARTCV, ARTXD, WWTXV, WXICD, WXICV, ZWCDP, ZWHDP.
df = pd.read_excel('Datasets/use_tot_sector.xlsx' , sheet_name='Commercial Sector')

# %%
df.head()
# Out:
#   State    1960    1961    1962    1963    1964    1965    1966    1967
# 0    AK    7307    7744    7941   10116   12898   15276   16031   18156  \
# 1    AL   57186   64744   71604   77702   82040   82000   85463   85537
# 2    AR   36006   36795   41057   44315   47870   53889   61254   66520
# 3    AZ   67122   50833   48940   53383   65190   58323   59715   69120
# 4    CA  435911  488193  514602  532666  551289  577322  623839  644067
#
#      1968  ...     2011     2012     2013     2014     2015     2016     2017
# 0   19463  ...    70816    69598    62922    63219    66983    59310    58839  \
# 1   96195  ...   257067   244920   256750   262497   263457   262883   254444
# 2   71836  ...   174606   170149   176523   182202   179155   175258   173138
# 3   71954  ...   347695   344047   350023   342287   347477   351903   355070
# 4  689567  ...  1538868  1489739  1430530  1432703  1462756  1458412  1473145
#
#       2018     2019     2020
# 0    57357    56911    57892
# 1   263742   257727   236206
# 2   184354   180162   169813
# 3   351624   347401   334261
# 4  1510417  1468097  1358322
#
# [5 rows x 62 columns]

# %% [markdown]
# # Data statistics

# %%
df.head()
# Out:
#   State    1960    1961    1962    1963    1964    1965    1966    1967
# 0    AK    7307    7744    7941   10116   12898   15276   16031   18156  \
# 1    AL   57186   64744   71604   77702   82040   82000   85463   85537
# 2    AR   36006   36795   41057   44315   47870   53889   61254   66520
# 3    AZ   67122   50833   48940   53383   65190   58323   59715   69120
# 4    CA  435911  488193  514602  532666  551289  577322  623839  644067
#
#      1968  ...     2011     2012     2013     2014     2015     2016     2017
# 0   19463  ...    70816    69598    62922    63219    66983    59310    58839  \
# 1   96195  ...   257067   244920   256750   262497   263457   262883   254444
# 2   71836  ...   174606   170149   176523   182202   179155   175258   173138
# 3   71954  ...   347695   344047   350023   342287   347477   351903   355070
# 4  689567  ...  1538868  1489739  1430530  1432703  1462756  1458412  1473145
#
#       2018     2019     2020
# 0    57357    56911    57892
# 1   263742   257727   236206
# 2   184354   180162   169813
# 3   351624   347401   334261
# 4  1510417  1468097  1358322
#
# [5 rows x 62 columns]

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964
# count  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  \
# mean   1.771024e+05  1.816625e+05  1.935526e+05  2.017086e+05  2.100072e+05
# std    6.357400e+05  6.520534e+05  6.943788e+05  7.241563e+05  7.533899e+05
# min    5.300000e+03  5.576000e+03  5.748000e+03  6.244000e+03  6.853000e+03
# 25%    2.605775e+04  2.877350e+04  3.073625e+04  3.071675e+04  3.312250e+04
# 50%    5.927250e+04  5.969900e+04  6.420400e+04  6.662400e+04  7.061900e+04
# 75%    9.428725e+04  9.902725e+04  1.046468e+05  1.024878e+05  1.067048e+05
# max    4.604662e+06  4.723224e+06  5.032369e+06  5.244424e+06  5.460190e+06
#
#                1965          1966          1967          1968          1969
# count  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  \
# mean   2.246218e+05  2.430209e+05  2.652077e+05  2.817902e+05  3.010799e+05
# std    8.065473e+05  8.727943e+05  9.517838e+05  1.010528e+06  1.078867e+06
# min    7.025000e+03  7.660000e+03  8.375000e+03  9.238000e+03  1.070600e+04
# 25%    3.233850e+04  3.467100e+04  3.713525e+04  3.960675e+04  4.287300e+04
# 50%    7.395800e+04  8.110450e+04  8.497650e+04  9.387200e+04  1.019050e+05
# 75%    1.129808e+05  1.283500e+05  1.394008e+05  1.534340e+05  1.658945e+05
# max    5.840164e+06  6.318543e+06  6.895401e+06  7.326545e+06  7.828079e+06
#
#        ...          2011          2012          2013          2014
# count  ...  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  \
# mean   ...  6.900314e+05  6.678895e+05  6.876589e+05  7.002965e+05
# std    ...  2.463870e+06  2.385004e+06  2.454624e+06  2.499544e+06
# min    ...  2.907400e+04  2.282000e+04  2.601900e+04  2.694700e+04
# 25%    ...  1.176475e+05  1.115130e+05  1.120848e+05  1.128055e+05
# 50%    ...  2.550890e+05  2.485295e+05  2.587415e+05  2.650000e+05
# 75%    ...  4.622942e+05  4.490335e+05  4.541745e+05  4.638560e+05
# max    ...  1.794082e+07  1.736513e+07  1.787913e+07  1.820771e+07
#
#                2015          2016          2017          2018          2019
# count  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01  \
# mean   6.965534e+05  6.919547e+05  6.871049e+05  7.083326e+05  6.916940e+05
# std    2.486202e+06  2.470078e+06  2.452840e+06  2.528525e+06  2.468964e+06
# min    2.765900e+04  2.620800e+04  2.464300e+04  2.753500e+04  2.593700e+04
# 25%    1.121162e+05  1.111652e+05  1.067565e+05  1.127065e+05  1.091645e+05
# 50%    2.642665e+05  2.646675e+05  2.557465e+05  2.656580e+05  2.587360e+05
# 75%    4.742048e+05  4.792468e+05  4.578525e+05  4.894128e+05  4.705808e+05
# max    1.811039e+07  1.799082e+07  1.786473e+07  1.841665e+07  1.798404e+07
#
#                2020
# count  5.200000e+01
# mean   6.435609e+05
# std    2.298159e+06
# min    2.528400e+04
# 25%    9.898600e+04
# 50%    2.341635e+05
# 75%    4.333518e+05
# max    1.673258e+07
#
# [8 rows x 61 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 62 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   52 non-null     object
#  1   1960    52 non-null     int64
#  2   1961    52 non-null     int64
#  3   1962    52 non-null     int64
#  4   1963    52 non-null     int64
#  5   1964    52 non-null     int64
#  6   1965    52 non-null     int64
#  7   1966    52 non-null     int64
#  8   1967    52 non-null     int64
#  9   1968    52 non-null     int64
#  10  1969    52 non-null     int64
#  11  1970    52 non-null     int64
#  12  1971    52 non-null     int64
#  13  1972    52 non-null     int64
#  14  1973    52 non-null     int64
#  15  1974    52 non-null     int64
#  16  1975    52 non-null     int64
#  17  1976    52 non-null     int64
#  18  1977    52 non-null     int64
#  19  1978    52 non-null     int64
#  20  1979    52 non-null     int64
#  21  1980    52 non-null     int64
#  22  1981    52 non-null     int64
#  23  1982    52 non-null     int64
#  24  1983    52 non-null     int64
#  25  1984    52 non-null     int64
#  26  1985    52 non-null     int64
#  27  1986    52 non-null     int64
#  28  1987    52 non-null     int64
#  29  1988    52 non-null     int64
#  30  1989    52 non-null     int64
#  31  1990    52 non-null     int64
#  32  1991    52 non-null     int64
#  33  1992    52 non-null     int64
#  34  1993    52 non-null     int64
#  35  1994    52 non-null     int64
#  36  1995    52 non-null     int64
#  37  1996    52 non-null     int64
#  38  1997    52 non-null     int64
#  39  1998    52 non-null     int64
#  40  1999    52 non-null     int64
#  41  2000    52 non-null     int64
#  42  2001    52 non-null     int64
#  43  2002    52 non-null     int64
#  44  2003    52 non-null     int64
#  45  2004    52 non-null     int64
#  46  2005    52 non-null     int64
#  47  2006    52 non-null     int64
#  48  2007    52 non-null     int64
#  49  2008    52 non-null     int64
#  50  2009    52 non-null     int64
#  51  2010    52 non-null     int64
#  52  2011    52 non-null     int64
#  53  2012    52 non-null     int64
#  54  2013    52 non-null     int64
#  55  2014    52 non-null     int64
#  56  2015    52 non-null     int64
#  57  2016    52 non-null     int64
#  58  2017    52 non-null     int64
#  59  2018    52 non-null     int64
#  60  2019    52 non-null     int64
#  61  2020    52 non-null     int64
# dtypes: int64(61), object(1)
# memory usage: 25.3+ KB

# %%
df.head()
# Out:
#   State    1960    1961    1962    1963    1964    1965    1966    1967
# 0    AK    7307    7744    7941   10116   12898   15276   16031   18156  \
# 1    AL   57186   64744   71604   77702   82040   82000   85463   85537
# 2    AR   36006   36795   41057   44315   47870   53889   61254   66520
# 3    AZ   67122   50833   48940   53383   65190   58323   59715   69120
# 4    CA  435911  488193  514602  532666  551289  577322  623839  644067
#
#      1968  ...     2011     2012     2013     2014     2015     2016     2017
# 0   19463  ...    70816    69598    62922    63219    66983    59310    58839  \
# 1   96195  ...   257067   244920   256750   262497   263457   262883   254444
# 2   71836  ...   174606   170149   176523   182202   179155   175258   173138
# 3   71954  ...   347695   344047   350023   342287   347477   351903   355070
# 4  689567  ...  1538868  1489739  1430530  1432703  1462756  1458412  1473145
#
#       2018     2019     2020
# 0    57357    56911    57892
# 1   263742   257727   236206
# 2   184354   180162   169813
# 3   351624   347401   334261
# 4  1510417  1468097  1358322
#
# [5 rows x 62 columns]

# %% [markdown]
# # Transformation of Data

# %%
df_trans = df.melt(id_vars=['State'] , var_name='Year', value_name='Yearly Data')
df_trans['Year'] = pd.to_datetime(df_trans['Year'], format='%Y')

df_trans
# Out:
#      State       Year  Yearly Data
# 0       AK 1960-01-01         7307
# 1       AL 1960-01-01        57186
# 2       AR 1960-01-01        36006
# 3       AZ 1960-01-01        67122
# 4       CA 1960-01-01       435911
# ...    ...        ...          ...
# 3167    WA 2020-01-01       330939
# 3168    WI 2020-01-01       337631
# 3169    WV 2020-01-01       102041
# 3170    WY 2020-01-01        53366
# 3171    US 2020-01-01     16732585
#
# [3172 rows x 3 columns]

# %% [markdown]
# # Modeling the Data
# ## Using ARIMA Model

# %%
os.makedirs('Plots/use_tot_Sector_data_Commercial_Sector/Arima_results_plots',exist_ok=True)

for State in df_trans['State'].unique():
        try:
            
            fig = go.Figure()

            # Get the energy consumption data for the current country and sector
            df_filter = df_trans[df_trans['State'] == State ][['Year', 'Yearly Data']]
            df_filter_index = df_filter.set_index('Year')

            train_data = df_filter[:-5]
            test_data = df_filter[-5:]
            
            # Prepare the data for modeling
            years = df_filter_index.index
            energy_consumption = df_filter_index.values.flatten()

                    # Split the data into training and testing
            # Use all data except the last 5 years for training
            Horizan = -5
            train_data = energy_consumption[:Horizan]
            test_data = energy_consumption[Horizan:]  # Use the last 5 years for testing

            # Fit the auto ARIMA model
            model = auto_arima(train_data, seasonal=False)
            model.fit(train_data)

            # Generate predictions
            predictions = model.predict(n_periods=len(test_data))
            predictions_ahead_in_future = model.predict(n_periods=len(test_data)+15)

            # Calculate evaluation metrics
            mae = mean_absolute_error(test_data, predictions)
            mse = mean_squared_error(test_data, predictions)
            mape = np.mean(np.abs((test_data - predictions) / test_data)) * 100

            print('Mean Absolute Error (MAE):', np.round(mae,2))
            print('Mean Squared Error (MSE):', np.round(mse,2))
            print('Mean Absolute Percentage Error (MAPE):', np.round(mape,2))
            
            # Plot the training data
            fig.add_trace(go.Scatter(
                x=years[:Horizan], y=train_data, mode='lines+markers', name='Training Data'))

            # Plot the predictions
            fig.add_trace(go.Scatter(
                x=years[Horizan:], y=test_data, mode='lines+markers', name='Actual'))
            fig.add_trace(go.Scatter(
                x=years[Horizan:], y=predictions, mode='lines+markers', name='Predicted'))

            fig.add_trace(go.Scatter(
                x=pd.date_range(start = years[Horizan],periods=15,freq='Y'), y=predictions_ahead_in_future, mode='lines+markers', name='Prediction till 2030'))

            # Update the layout
            fig.update_layout(title=f'Commercial Sector : Energy Consumption Forecast State : {State} using ARIMA Model',
                            xaxis_title='Year', yaxis_title='Energy Consumption')

            # Show the plot
            fig.show()
            # print(State,msn)
            fig.write_image(f'Plots/use_tot_Sector_data_Commercial_Sector/Arima_results_plots/{State}.png')
            # break
        except:
            print('Error occoured in Combination State : {} and MSN : {} Due NaN Value'.format(State,mse))
# Out:
# Mean Absolute Error (MAE): 8921.2
# Mean Squared Error (MSE): 80390201.2
# Mean Absolute Percentage Error (MAPE): 15.39
# Mean Absolute Error (MAE): 19707.75
# Mean Squared Error (MSE): 591544976.31
# Mean Absolute Percentage Error (MAPE): 7.96
# Mean Absolute Error (MAE): 10418.13
# Mean Squared Error (MSE): 152639796.83
# Mean Absolute Percentage Error (MAPE): 6.0
# Mean Absolute Error (MAE): 14717.29
# Mean Squared Error (MSE): 409635146.05
# Mean Absolute Percentage Error (MAPE): 4.31
# Mean Absolute Error (MAE): 65087.13
# Mean Squared Error (MSE): 9050373040.95
# Mean Absolute Percentage Error (MAPE): 4.65
# Mean Absolute Error (MAE): 12122.35
# Mean Squared Error (MSE): 240269616.49
# Mean Absolute Percentage Error (MAPE): 4.23
# Mean Absolute Error (MAE): 21052.73
# Mean Squared Error (MSE): 560409118.0
# Mean Absolute Percentage Error (MAPE): 11.62
# Mean Absolute Error (MAE): 11485.87
# Mean Squared Error (MSE): 229771389.18
# Mean Absolute Percentage Error (MAPE): 12.31
# Mean Absolute Error (MAE): 2362.6
# Mean Squared Error (MSE): 8322238.2
# Mean Absolute Percentage Error (MAPE): 3.92
# Mean Absolute Error (MAE): 89775.17
# Mean Squared Error (MSE): 11393009253.45
# Mean Absolute Percentage Error (MAPE): 9.46
# Mean Absolute Error (MAE): 42939.13
# Mean Squared Error (MSE): 2809597328.57
# Mean Absolute Percentage Error (MAPE): 8.26
# Mean Absolute Error (MAE): 1082.86
# Mean Squared Error (MSE): 3620077.01
# Mean Absolute Percentage Error (MAPE): 2.7
# Mean Absolute Error (MAE): 16305.13
# Mean Squared Error (MSE): 336486591.89
# Mean Absolute Percentage Error (MAPE): 8.62
# Mean Absolute Error (MAE): 1910.53
# Mean Squared Error (MSE): 6310603.01
# Mean Absolute Percentage Error (MAPE): 2.11
# Mean Absolute Error (MAE): 27970.9
# Mean Squared Error (MSE): 2031215200.06
# Mean Absolute Percentage Error (MAPE): 3.69
# Mean Absolute Error (MAE): 28985.69
# Mean Squared Error (MSE): 1179580414.93
# Mean Absolute Percentage Error (MAPE): 8.22
# Mean Absolute Error (MAE): 12366.78
# Mean Squared Error (MSE): 235929533.97
# Mean Absolute Percentage Error (MAPE): 5.88
# Mean Absolute Error (MAE): 19471.89
# Mean Squared Error (MSE): 657970051.22
# Mean Absolute Percentage Error (MAPE): 7.91
# Mean Absolute Error (MAE): 10490.0
# Mean Squared Error (MSE): 285777309.2
# Mean Absolute Percentage Error (MAPE): 4.33
# Mean Absolute Error (MAE): 12039.4
# Mean Squared Error (MSE): 283727730.2
# Mean Absolute Percentage Error (MAPE): 3.15
# Mean Absolute Error (MAE): 48974.8
# Mean Squared Error (MSE): 3337247226.8
# Mean Absolute Percentage Error (MAPE): 12.77
# Mean Absolute Error (MAE): 3867.52
# Mean Squared Error (MSE): 19505259.01
# Mean Absolute Percentage Error (MAPE): 5.96
# Mean Absolute Error (MAE): 23976.18
# Mean Squared Error (MSE): 1084112565.1
# Mean Absolute Percentage Error (MAPE): 4.1
# Mean Absolute Error (MAE): 19401.1
# Mean Squared Error (MSE): 543858717.59
# Mean Absolute Percentage Error (MAPE): 5.5
# Mean Absolute Error (MAE): 25045.64
# Mean Squared Error (MSE): 1072745492.75
# Mean Absolute Percentage Error (MAPE): 6.38
# Mean Absolute Error (MAE): 12783.18
# Mean Squared Error (MSE): 236282629.47
# Mean Absolute Percentage Error (MAPE): 8.68
# Mean Absolute Error (MAE): 6423.4
# Mean Squared Error (MSE): 50720279.4
# Mean Absolute Percentage Error (MAPE): 7.62
# Mean Absolute Error (MAE): 38234.87
# Mean Squared Error (MSE): 2253878830.71
# Mean Absolute Percentage Error (MAPE): 6.87
# Mean Absolute Error (MAE): 3828.71
# Mean Squared Error (MSE): 21741069.81
# Mean Absolute Percentage Error (MAPE): 4.28
# Mean Absolute Error (MAE): 5564.36
# Mean Squared Error (MSE): 33718048.92
# Mean Absolute Percentage Error (MAPE): 3.98
# Mean Absolute Error (MAE): 5445.22
# Mean Squared Error (MSE): 43504529.0
# Mean Absolute Percentage Error (MAPE): 7.98
# Mean Absolute Error (MAE): 61691.84
# Mean Squared Error (MSE): 4665203696.99
# Mean Absolute Percentage Error (MAPE): 11.27
# Mean Absolute Error (MAE): 7833.82
# Mean Squared Error (MSE): 90804950.64
# Mean Absolute Percentage Error (MAPE): 6.51
# Mean Absolute Error (MAE): 13868.07
# Mean Squared Error (MSE): 247745072.49
# Mean Absolute Percentage Error (MAPE): 9.31
# Mean Absolute Error (MAE): 68421.85
# Mean Squared Error (MSE): 8012050786.66
# Mean Absolute Percentage Error (MAPE): 6.44
# Mean Absolute Error (MAE): 53881.44
# Mean Squared Error (MSE): 4170573443.73
# Mean Absolute Percentage Error (MAPE): 8.14
# Mean Absolute Error (MAE): 25579.85
# Mean Squared Error (MSE): 918953445.91
# Mean Absolute Percentage Error (MAPE): 10.78
# Mean Absolute Error (MAE): 18427.47
# Mean Squared Error (MSE): 372098943.83
# Mean Absolute Percentage Error (MAPE): 9.46
# Mean Absolute Error (MAE): 67489.64
# Mean Squared Error (MSE): 7451101886.58
# Mean Absolute Percentage Error (MAPE): 11.85
# Mean Absolute Error (MAE): 3071.0
# Mean Squared Error (MSE): 11497227.8
# Mean Absolute Percentage Error (MAPE): 6.71
# Mean Absolute Error (MAE): 17194.78
# Mean Squared Error (MSE): 498947302.53
# Mean Absolute Percentage Error (MAPE): 6.52
# Mean Absolute Error (MAE): 2182.75
# Mean Squared Error (MSE): 8591154.26
# Mean Absolute Percentage Error (MAPE): 3.49
# Mean Absolute Error (MAE): 25964.93
# Mean Squared Error (MSE): 1326730901.3
# Mean Absolute Percentage Error (MAPE): 6.12
# Mean Absolute Error (MAE): 40510.53
# Mean Squared Error (MSE): 2605240986.05
# Mean Absolute Percentage Error (MAPE): 2.5
# Mean Absolute Error (MAE): 3442.35
# Mean Squared Error (MSE): 15188766.5
# Mean Absolute Percentage Error (MAPE): 2.0
# Mean Absolute Error (MAE): 23739.04
# Mean Squared Error (MSE): 817361468.53
# Mean Absolute Percentage Error (MAPE): 3.85
# Mean Absolute Error (MAE): 2770.15
# Mean Squared Error (MSE): 8932233.42
# Mean Absolute Percentage Error (MAPE): 10.85
# Mean Absolute Error (MAE): 20974.58
# Mean Squared Error (MSE): 972706392.8
# Mean Absolute Percentage Error (MAPE): 6.08
# Mean Absolute Error (MAE): 17172.58
# Mean Squared Error (MSE): 615905757.26
# Mean Absolute Percentage Error (MAPE): 4.94
# Mean Absolute Error (MAE): 8029.76
# Mean Squared Error (MSE): 97796087.42
# Mean Absolute Percentage Error (MAPE): 7.55
# Mean Absolute Error (MAE): 7519.56
# Mean Squared Error (MSE): 73079023.3
# Mean Absolute Percentage Error (MAPE): 13.28
# Mean Absolute Error (MAE): 1049300.02
# Mean Squared Error (MSE): 1775901208006.94
# Mean Absolute Percentage Error (MAPE): 6.05

# %% [markdown]
# ## Using SARIMA Model

# %%
os.makedirs('Plots/use_tot_Sector_data_Commercial_Sector/Sarima_results_plots',exist_ok=True)

for State in df_trans['State'].unique():
        try:
            
            fig = go.Figure()

            # Get the energy consumption data for the current country and sector
            df_filter = df_trans[df_trans['State'] == State ][['Year', 'Yearly Data']]
            df_filter_index = df_filter.set_index('Year')

            train_data = df_filter[:-5]
            test_data = df_filter[-5:]
            
            # Prepare the data for modeling
            years = df_filter_index.index
            energy_consumption = df_filter_index.values.flatten()

                    # Split the data into training and testing
            # Use all data except the last 5 years for training
            Horizan = -5
            train_data = energy_consumption[:Horizan]
            test_data = energy_consumption[Horizan:]  # Use the last 5 years for testing

            # Fit the auto ARIMA model
            model = auto_arima(train_data, seasonal=False)
            model.fit(train_data)

            # Generate predictions
            predictions = model.predict(n_periods=len(test_data))
            predictions_ahead_in_future = model.predict(n_periods=len(test_data)+15)

            # Calculate evaluation metrics
            mae = mean_absolute_error(test_data, predictions)
            mse = mean_squared_error(test_data, predictions)
            mape = np.mean(np.abs((test_data - predictions) / test_data)) * 100

            print('Mean Absolute Error (MAE):', np.round(mae,2))
            print('Mean Squared Error (MSE):', np.round(mse,2))
            print('Mean Absolute Percentage Error (MAPE):', np.round(mape,2))
            
            # Plot the training data
            fig.add_trace(go.Scatter(
                x=years[:Horizan], y=train_data, mode='lines+markers', name='Training Data'))

            # Plot the predictions
            fig.add_trace(go.Scatter(
                x=years[Horizan:], y=test_data, mode='lines+markers', name='Actual'))
            fig.add_trace(go.Scatter(
                x=years[Horizan:], y=predictions, mode='lines+markers', name='Predicted'))

            fig.add_trace(go.Scatter(
                x=pd.date_range(start = years[Horizan],periods=15,freq='Y'), y=predictions_ahead_in_future, mode='lines+markers', name='Prediction till 2030'))

            # Update the layout
            fig.update_layout(title=f'Commercial Sector : Energy Consumption Forecast State : {State} using SARIMA Model',
                            xaxis_title='Year', yaxis_title='Energy Consumption')

            # Show the plot
            fig.show()
            # print(State,msn)
            fig.write_image(f'Plots/use_tot_Sector_data_Commercial_Sector/Sarima_results_plots/{State}.png')
            # break
        except:
            print('Error occoured in Combination State : {} and MSN : {} Due NaN Value'.format(State,mse))
        # break
# Out:
# Mean Absolute Error (MAE): 8921.2
# Mean Squared Error (MSE): 80390201.2
# Mean Absolute Percentage Error (MAPE): 15.39
# Mean Absolute Error (MAE): 19707.75
# Mean Squared Error (MSE): 591544976.31
# Mean Absolute Percentage Error (MAPE): 7.96
# Mean Absolute Error (MAE): 10418.13
# Mean Squared Error (MSE): 152639796.83
# Mean Absolute Percentage Error (MAPE): 6.0
# Mean Absolute Error (MAE): 14717.29
# Mean Squared Error (MSE): 409635146.05
# Mean Absolute Percentage Error (MAPE): 4.31
# Mean Absolute Error (MAE): 65087.13
# Mean Squared Error (MSE): 9050373040.95
# Mean Absolute Percentage Error (MAPE): 4.65
# Mean Absolute Error (MAE): 12122.35
# Mean Squared Error (MSE): 240269616.49
# Mean Absolute Percentage Error (MAPE): 4.23
# Mean Absolute Error (MAE): 21052.73
# Mean Squared Error (MSE): 560409118.0
# Mean Absolute Percentage Error (MAPE): 11.62
# Mean Absolute Error (MAE): 11485.87
# Mean Squared Error (MSE): 229771389.18
# Mean Absolute Percentage Error (MAPE): 12.31
# Mean Absolute Error (MAE): 2362.6
# Mean Squared Error (MSE): 8322238.2
# Mean Absolute Percentage Error (MAPE): 3.92
# Mean Absolute Error (MAE): 89775.17
# Mean Squared Error (MSE): 11393009253.45
# Mean Absolute Percentage Error (MAPE): 9.46
# Mean Absolute Error (MAE): 42939.13
# Mean Squared Error (MSE): 2809597328.57
# Mean Absolute Percentage Error (MAPE): 8.26
# Mean Absolute Error (MAE): 1082.86
# Mean Squared Error (MSE): 3620077.01
# Mean Absolute Percentage Error (MAPE): 2.7
# Mean Absolute Error (MAE): 16305.13
# Mean Squared Error (MSE): 336486591.89
# Mean Absolute Percentage Error (MAPE): 8.62
# Mean Absolute Error (MAE): 1910.53
# Mean Squared Error (MSE): 6310603.01
# Mean Absolute Percentage Error (MAPE): 2.11
# Mean Absolute Error (MAE): 27970.9
# Mean Squared Error (MSE): 2031215200.06
# Mean Absolute Percentage Error (MAPE): 3.69
# Mean Absolute Error (MAE): 28985.69
# Mean Squared Error (MSE): 1179580414.93
# Mean Absolute Percentage Error (MAPE): 8.22
# Mean Absolute Error (MAE): 12366.78
# Mean Squared Error (MSE): 235929533.97
# Mean Absolute Percentage Error (MAPE): 5.88
# Mean Absolute Error (MAE): 19471.89
# Mean Squared Error (MSE): 657970051.22
# Mean Absolute Percentage Error (MAPE): 7.91
# Mean Absolute Error (MAE): 10490.0
# Mean Squared Error (MSE): 285777309.2
# Mean Absolute Percentage Error (MAPE): 4.33
# Mean Absolute Error (MAE): 12039.4
# Mean Squared Error (MSE): 283727730.2
# Mean Absolute Percentage Error (MAPE): 3.15
# Mean Absolute Error (MAE): 48974.8
# Mean Squared Error (MSE): 3337247226.8
# Mean Absolute Percentage Error (MAPE): 12.77
# Mean Absolute Error (MAE): 3867.52
# Mean Squared Error (MSE): 19505259.01
# Mean Absolute Percentage Error (MAPE): 5.96
# Mean Absolute Error (MAE): 23976.18
# Mean Squared Error (MSE): 1084112565.1
# Mean Absolute Percentage Error (MAPE): 4.1
# Mean Absolute Error (MAE): 19401.1
# Mean Squared Error (MSE): 543858717.59
# Mean Absolute Percentage Error (MAPE): 5.5
# Mean Absolute Error (MAE): 25045.64
# Mean Squared Error (MSE): 1072745492.75
# Mean Absolute Percentage Error (MAPE): 6.38
# Mean Absolute Error (MAE): 12783.18
# Mean Squared Error (MSE): 236282629.47
# Mean Absolute Percentage Error (MAPE): 8.68
# Mean Absolute Error (MAE): 6423.4
# Mean Squared Error (MSE): 50720279.4
# Mean Absolute Percentage Error (MAPE): 7.62
# Mean Absolute Error (MAE): 38234.87
# Mean Squared Error (MSE): 2253878830.71
# Mean Absolute Percentage Error (MAPE): 6.87
# Mean Absolute Error (MAE): 3828.71
# Mean Squared Error (MSE): 21741069.81
# Mean Absolute Percentage Error (MAPE): 4.28
# Mean Absolute Error (MAE): 5564.36
# Mean Squared Error (MSE): 33718048.92
# Mean Absolute Percentage Error (MAPE): 3.98
# Mean Absolute Error (MAE): 5445.22
# Mean Squared Error (MSE): 43504529.0
# Mean Absolute Percentage Error (MAPE): 7.98
# Mean Absolute Error (MAE): 61691.84
# Mean Squared Error (MSE): 4665203696.99
# Mean Absolute Percentage Error (MAPE): 11.27
# Mean Absolute Error (MAE): 7833.82
# Mean Squared Error (MSE): 90804950.64
# Mean Absolute Percentage Error (MAPE): 6.51
# Mean Absolute Error (MAE): 13868.07
# Mean Squared Error (MSE): 247745072.49
# Mean Absolute Percentage Error (MAPE): 9.31
# Mean Absolute Error (MAE): 68421.85
# Mean Squared Error (MSE): 8012050786.66
# Mean Absolute Percentage Error (MAPE): 6.44
# Mean Absolute Error (MAE): 53881.44
# Mean Squared Error (MSE): 4170573443.73
# Mean Absolute Percentage Error (MAPE): 8.14
# Mean Absolute Error (MAE): 25579.85
# Mean Squared Error (MSE): 918953445.91
# Mean Absolute Percentage Error (MAPE): 10.78
# Mean Absolute Error (MAE): 18427.47
# Mean Squared Error (MSE): 372098943.83
# Mean Absolute Percentage Error (MAPE): 9.46
# Mean Absolute Error (MAE): 67489.64
# Mean Squared Error (MSE): 7451101886.58
# Mean Absolute Percentage Error (MAPE): 11.85
# Mean Absolute Error (MAE): 3071.0
# Mean Squared Error (MSE): 11497227.8
# Mean Absolute Percentage Error (MAPE): 6.71
# Mean Absolute Error (MAE): 17194.78
# Mean Squared Error (MSE): 498947302.53
# Mean Absolute Percentage Error (MAPE): 6.52
# Mean Absolute Error (MAE): 2182.75
# Mean Squared Error (MSE): 8591154.26
# Mean Absolute Percentage Error (MAPE): 3.49
# Mean Absolute Error (MAE): 25964.93
# Mean Squared Error (MSE): 1326730901.3
# Mean Absolute Percentage Error (MAPE): 6.12
# Mean Absolute Error (MAE): 40510.53
# Mean Squared Error (MSE): 2605240986.05
# Mean Absolute Percentage Error (MAPE): 2.5
# Mean Absolute Error (MAE): 3442.35
# Mean Squared Error (MSE): 15188766.5
# Mean Absolute Percentage Error (MAPE): 2.0
# Mean Absolute Error (MAE): 23739.04
# Mean Squared Error (MSE): 817361468.53
# Mean Absolute Percentage Error (MAPE): 3.85
# Mean Absolute Error (MAE): 2770.15
# Mean Squared Error (MSE): 8932233.42
# Mean Absolute Percentage Error (MAPE): 10.85
# Mean Absolute Error (MAE): 20974.58
# Mean Squared Error (MSE): 972706392.8
# Mean Absolute Percentage Error (MAPE): 6.08
# Mean Absolute Error (MAE): 17172.58
# Mean Squared Error (MSE): 615905757.26
# Mean Absolute Percentage Error (MAPE): 4.94
# Mean Absolute Error (MAE): 8029.76
# Mean Squared Error (MSE): 97796087.42
# Mean Absolute Percentage Error (MAPE): 7.55
# Mean Absolute Error (MAE): 7519.56
# Mean Squared Error (MSE): 73079023.3
# Mean Absolute Percentage Error (MAPE): 13.28
# Mean Absolute Error (MAE): 1049300.02
# Mean Squared Error (MSE): 1775901208006.94
# Mean Absolute Percentage Error (MAPE): 6.05
